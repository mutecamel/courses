# %%
x=5
x=3*5
print(x)
# Out:
# 15

# %%
x = 5
x = "a" * x
print(x)
# Out:
# aaaaa

# %%
x = 5
x = "a" * x
print(x)
x = 9
x * 3
# Out:
# aaaaa
# 27

# %%
a = [4,2,9]
a
# Out:
# [4, 2, 9]

# %%
a.pop()
# Out:
# 9

# %%
a
# Out:
# [4, 2]

# %%
print(a)
# Out:
# [4, 2]

# %%
a.append(7)

# %%
a
# Out:
# [4, 2, 7]

# %%
import time
while True:
    print('hello')
    time.sleep(3)
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
基础文本格式
这是加粗文本，这是斜体文本，这是粗斜体文本。
简单列表
苹果
香蕉
橙子

第一步
第二步
第三步
代码示例
python
运行
# 打印Hello World
print("Hello JupyterLab!")

# 计算1+1
result = 1 + 1
print(f"1 + 1 = {result}")
数学公式
E=mc 
2
 
表格
姓名	年龄	职业
张三	28	工程师
李四	32	设计师
